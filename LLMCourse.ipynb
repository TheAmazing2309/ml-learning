# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAmazing2309/ml-learning/blob/main/LLMCourse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier([
    "This course is so much fun to go through!",
    "This course is extremely boring"
])
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998455047607422},
#  {'label': 'NEGATIVE', 'score': 0.999789297580719}]

# %%
zero_shot_classifier = pipeline("zero-shot-classification")
zero_shot_classifier(
    "I am learning how to use the Hugging Face transformers library!",
    candidate_labels = ["Machine Learning", "Mathematics", "Literature"]
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'I am learning how to use the Hugging Face transformers library!',
#  'labels': ['Machine Learning', 'Mathematics', 'Literature'],
#  'scores': [0.7191381454467773, 0.16888834536075592, 0.11197347939014435]}

# %%
# generator = pipeline("text-generation")
# generator(
#     "This summer I want to ",
#     num_return_sequences = 2,
#     max_length = 25
# )

# %%
mask = pipeline("fill-mask", model="bert-base-cased")
mask("This course will teach you all about [MASK] models.", top_k=2)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: bert-base-cased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# bert.pooler.dense.weight    | UNEXPECTED |  |
# cls.seq_relationship.weight | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# [{'score': 0.2596319019794464,
#   'token': 1648,
#   'token_str': 'role',
#   'sequence': 'This course will teach you all about role models.'},
#  {'score': 0.09427254647016525,
#   'token': 1103,
#   'token_str': 'the',
#   'sequence': 'This course will teach you all about the models.'}]

# %%
ner = pipeline("ner")
ner("My name is Jonathan and I go to school at Stuyvesant High School in Manhattan.")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity': 'I-PER',
#   'score': np.float32(0.99840754),
#   'index': 4,
#   'word': 'Jonathan',
#   'start': 11,
#   'end': 19},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.50612295),
#   'index': 11,
#   'word': 'St',
#   'start': 42,
#   'end': 44},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.7422112),
#   'index': 12,
#   'word': '##uy',
#   'start': 44,
#   'end': 46},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.63846946),
#   'index': 13,
#   'word': '##ves',
#   'start': 46,
#   'end': 49},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.5515254),
#   'index': 14,
#   'word': '##ant',
#   'start': 49,
#   'end': 52},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.65550923),
#   'index': 15,
#   'word': 'High',
#   'start': 53,
#   'end': 57},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.51972973),
#   'index': 16,
#   'word': 'School',
#   'start': 58,
#   'end': 64},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.99295866),
#   'index': 18,
#   'word': 'Manhattan',
#   'start': 68,
#   'end': 77}]
